# %% [markdown]
# # Python test

# %%
import matplotlib.pyplot as plt

x  = [1, 2, 3, 4, 5, 6, 7, 8, 9]
y1 = [1, 3, 5, 3, 1, 3, 5, 3, 1]
y2 = [2, 4, 6, 4, 2, 4, 6, 4, 2]
plt.plot(x, y1, label="line L")
plt.plot(x, y2, label="line H")
plt.plot()

plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("Line Graph Example")
plt.legend()
plt.show()

# %%
import PyDST

conn = PyDST.connection(language = 'da')

# %%
res = conn.get_tables('02')
res.info
# Out:
# Getting all tables under topic code(s) {topics}
#            ID                                        Description  \
# 0      FOLK1A                        Folketal den 1. i kvartalet
# 1      FOLK1B                        Folketal den 1. i kvartalet
# 2      FOLK1C                        Folketal den 1. i kvartalet
# 3      FOLK1D                        Folketal den 1. i kvartalet
# 4      FOLK1E                        Folketal den 1. i kvartalet
# 5       FOLK2                                 Folketal 1. januar
# 6       FOLK3                                 Folketal 1. januar
# 7          FT       Folketal (summariske tal fra folketællinger)
# 8       BEF5F  Personer født på Færøerne og bosat i Danmark 1...
# 9       BEF5G  Personer født i Grønland og bosat i Danmark 1....
# 10       BEF5                             Folketal pr. 1. januar
# 11        BY3                                 Folketal 1. januar
# 12        BY1                                 Folketal 1. januar
# 13        BY2                                 Folketal 1. januar
# 14       BEF4                                 Folketal 1. januar
# 15      HISB3                           Nøgletal om befolkningen
# 16      BEV22      Befolkningens udvikling (foreløbig opgørelse)
# 17     BEV107                            Befolkningens udvikling
# 18     GALDER                                   Gennemsnitsalder
# 19        KM1                        Folketal den 1. i kvartalet
# 20        KM5                                 Folketal 1. januar
# 21   KMSTA003                            Befolkningens udvikling
# 22    FRDK118      Befolkningsfremskrivning 2018 for hele landet
# 23    FRLD118                      Befolkningsfremskrivning 2018
# 24    FRKM118                      Befolkningsfremskrivning 2018
# 25    FRDK218  Nøgletal 2018: Fremskrivning af befolkningens ...
# 26    FRLD218  Nøgletal 2018: Fremskrivning af befolkningens ...
# 27    FRKM218  Nøgletal 2018: Fremskrivning af befolkningens ...
# 28    FRDK318  Forudsætninger vedrørende fertilitet til befol...
# 29    FRDK418  Forudsætninger vedrørende dødelighed til befol...
# ..        ...                                                ...
# 127   FV15S09   Folketingsvalget 2015 for Vestjyllands Storkreds
# 128   FV15S10   Folketingsvalget 2015 for Nordjyllands Storkreds
# 129  FV15KAND          Opstillede kandidaters personlige stemmer
# 130     KVRES                       Valg til kommunalbestyrelser
# 131    VALGK3                       Valg til kommunalbestyrelser
# 132     AKVA3                                Valg til regionsråd
# 133     EVKOM                              Europa-Parlamentsvalg
# 134   EV14TOT                       Europa-Parlamentsvalget 2014
# 135   EV14S01                       Europa-Parlamentsvalget 2014
# 136   EV14S02                       Europa-Parlamentsvalget 2014
# 137   EV14S03                       Europa-Parlamentsvalget 2014
# 138   EV14S04                       Europa-Parlamentsvalget 2014
# 139   EV14S05                       Europa-Parlamentsvalget 2014
# 140   EV14S06                       Europa-Parlamentsvalget 2014
# 141   EV14S07                       Europa-Parlamentsvalget 2014
# 142   EV14S08                       Europa-Parlamentsvalget 2014
# 143   EV14S09                       Europa-Parlamentsvalget 2014
# 144   EV14S10                       Europa-Parlamentsvalget 2014
# 145     FAKOM                                  Folkeafstemninger
# 146   FA15TOT  Folkeafstemning om omdannelse af retsforbehold...
# 147   FA15S01  Folkeafstemning om omdannelse af retsforbehold...
# 148   FA15S02  Folkeafstemning om omdannelse af retsforbehold...
# 149   FA15S03  Folkeafstemning om omdannelse af retsforbehold...
# 150   FA15S04  Folkeafstemning om omdannelse af retsforbehold...
# 151   FA15S05  Folkeafstemning om omdannelse af retsforbehold...
# 152   FA15S06  Folkeafstemning om omdannelse af retsforbehold...
# 153   FA15S07  Folkeafstemning om omdannelse af retsforbehold...
# 154   FA15S08  Folkeafstemning om omdannelse af retsforbehold...
# 155   FA15S09  Folkeafstemning om omdannelse af retsforbehold...
# 156   FA15S10  Folkeafstemning om omdannelse af retsforbehold...
#
#                                              Variables                 Unit  \
# 0                [område, køn, alder, civilstand, tid]                antal
# 1           [område, køn, alder, statsborgerskab, tid]                antal
# 2    [område, køn, alder, herkomst, oprindelsesland...                antal
# 3           [område, køn, alder, statsborgerskab, tid]                antal
# 4                  [område, køn, alder, herkomst, tid]                antal
# 5    [alder, køn, herkomst, statsborgerskab, oprind...                antal
# 6           [fødselsdag, fødselsmåned, fødselsår, tid]                antal
# 7                                [hovedlandsdele, tid]                antal
# 8              [køn, alder, forældrenes fødested, tid]                antal
# 9              [køn, alder, forældrenes fødested, tid]                antal
# 10                         [køn, alder, fødeland, tid]                antal
# 11   [byområder og landdistrikter, folketal, areal ...                    -
# 12      [byområder og landdistrikter, alder, køn, tid]                antal
# 13             [kommune, bystørrelse, alder, køn, tid]                antal
# 14                                          [øer, tid]                antal
# 15                                [bevægelsesart, tid]                antal
# 16                   [område, bevægelsesart, køn, tid]                antal
# 17                   [område, bevægelsesart, køn, tid]                antal
# 18                                 [kommune, køn, tid]                 gns.
# 19                  [sogn, folkekirkemedlemsskab, tid]                antal
# 20      [sogn, køn, alder, folkekirkemedlemsskab, tid]                antal
# 21                             [sogn, bevægelser, tid]                antal
# 22                         [herkomst, køn, alder, tid]                antal
# 23                           [område, alder, køn, tid]                antal
# 24                           [område, alder, køn, tid]                antal
# 25                      [herkomst, bevægelsesart, tid]                antal
# 26                        [område, bevægelsesart, tid]                antal
# 27                        [område, bevægelsesart, tid]                antal
# 28                              [alder, herkomst, tid]  fertilitetskvotient
# 29                 [køn, alder, dødelighedstavle, tid]                    -
# ..                                                 ...                  ...
# 127                        [valgresultat, område, tid]                antal
# 128                        [valgresultat, område, tid]                antal
# 129  [opstillede kandidater, valgresultat, parti, o...                antal
# 130                        [område, valgresultat, tid]                antal
# 131       [område, parti, stemmer/kandidater/køn, tid]                antal
# 132       [område, parti, stemmer/kandidater/køn, tid]                antal
# 133                        [valgresultat, område, tid]                antal
# 134                        [valgresultat, område, tid]                antal
# 135                        [valgresultat, område, tid]                antal
# 136                        [valgresultat, område, tid]                antal
# 137                        [valgresultat, område, tid]                antal
# 138                        [valgresultat, område, tid]                antal
# 139                        [valgresultat, område, tid]                antal
# 140                        [valgresultat, område, tid]                antal
# 141                        [valgresultat, område, tid]                antal
# 142                        [valgresultat, område, tid]                antal
# 143                        [valgresultat, område, tid]                antal
# 144                        [valgresultat, område, tid]                antal
# 145                        [valgresultat, område, tid]                antal
# 146                        [valgresultat, område, tid]                antal
# 147                        [valgresultat, område, tid]                antal
# 148                        [valgresultat, område, tid]                antal
# 149                        [valgresultat, område, tid]                antal
# 150                        [valgresultat, område, tid]                antal
# 151                        [valgresultat, område, tid]                antal
# 152                        [valgresultat, område, tid]                antal
# 153                        [valgresultat, område, tid]                antal
# 154                        [valgresultat, område, tid]                antal
# 155                        [valgresultat, område, tid]                antal
# 156                        [valgresultat, område, tid]                antal
#
#             Last updated First observation Latest observation  Active
# 0    2018-11-09T08:00:00            2008K1             2018K4    True
# 1    2018-11-09T08:00:00            2008K1             2018K4    True
# 2    2018-11-09T08:00:00            2008K1             2018K4    True
# 3    2018-11-09T08:00:00            2008K1             2018K4    True
# 4    2018-11-09T08:00:00            2008K1             2018K4    True
# 5    2018-02-09T08:00:00              1980               2018    True
# 6    2018-02-09T08:00:00              2008               2018    True
# 7    2018-02-09T08:00:00              1769               2018    True
# 8    2018-02-09T08:00:00              2008               2018    True
# 9    2018-02-09T08:00:00              2008               2018    True
# 10   2018-02-09T08:00:00              1990               2018    True
# 11   2018-06-11T08:00:00              2017               2017    True
# 12   2018-04-18T08:00:00              2010               2018    True
# 13   2018-04-18T08:00:00              2010               2018    True
# 14   2018-05-18T08:00:00              1901               2018    True
# 15   2018-02-21T08:00:00              1901               2018    True
# 16   2018-11-09T08:00:00            2007K2             2018K3    True
# 17   2018-02-21T08:00:00              2006               2017    True
# 18   2018-02-09T08:00:00              2005               2018    True
# 19   2018-08-23T08:00:00            2007K1             2018K3    True
# 20   2018-10-17T08:00:00              2007               2018    True
# 21   2018-03-28T08:00:00              2015               2017    True
# 22   2018-05-08T08:00:00              2018               2060    True
# 23   2018-05-08T08:00:00              2018               2045    True
# 24   2018-05-08T08:00:00              2018               2045    True
# 25   2018-05-08T08:00:00              2018               2060    True
# 26   2018-05-08T08:00:00              2018               2045    True
# 27   2018-05-08T08:00:00              2018               2045    True
# 28   2018-05-08T08:00:00              2018               2059    True
# 29   2018-05-08T08:00:00              2018               2059    True
# ..                   ...               ...                ...     ...
# 127  2015-07-02T09:00:00              2015               2015    True
# 128  2015-07-02T09:00:00              2015               2015    True
# 129  2015-07-02T09:00:00              2015               2015    True
# 130  2018-08-04T08:00:00              2005               2017    True
# 131  2018-07-18T08:00:00              2005               2017    True
# 132  2018-03-16T08:00:00              2005               2017    True
# 133  2016-03-01T09:00:00              2009               2014    True
# 134  2014-06-11T09:00:00              2014               2014    True
# 135  2014-06-04T09:00:00              2014               2014    True
# 136  2014-06-04T09:00:00              2014               2014    True
# 137  2014-06-04T09:00:00              2014               2014    True
# 138  2014-06-04T09:00:00              2014               2014    True
# 139  2014-06-04T09:00:00              2014               2014    True
# 140  2014-06-04T09:00:00              2014               2014    True
# 141  2014-06-04T09:00:00              2014               2014    True
# 142  2014-06-04T09:00:00              2014               2014    True
# 143  2014-06-04T09:00:00              2014               2014    True
# 144  2014-06-04T09:00:00              2014               2014    True
# 145  2016-03-01T09:00:00              2014               2015    True
# 146  2015-12-11T09:00:00              2015               2015    True
# 147  2015-12-11T09:00:00              2015               2015    True
# 148  2015-12-11T09:00:00              2015               2015    True
# 149  2015-12-11T09:00:00              2015               2015    True
# 150  2015-12-11T09:00:00              2015               2015    True
# 151  2015-12-11T09:00:00              2015               2015    True
# 152  2015-12-11T09:00:00              2015               2015    True
# 153  2015-12-11T09:00:00              2015               2015    True
# 154  2015-12-11T09:00:00              2015               2015    True
# 155  2015-12-11T09:00:00              2015               2015    True
# 156  2015-12-11T09:00:00              2015               2015    True
#
# [157 rows x 8 columns]

# %%
meta = conn.get_metadata('FOLK1A')
meta.variables
# Out:
# Getting metadata for table FOLK1A
# ['område', 'køn', 'alder', 'civilstand', 'tid']

# %%
resp = conn.get_data(
                table_id = 'FOLK1A',
                variables = ['Tid', 'Område'],
                values = {'Tid': ['2008K2']}
                     )
data = resp.df
# Out:
# Getting table FOLK1A, variables are ['Tid', 'Område']
#         values are {'Tid': ['2008K2']}
# No values specificed for område setting values to all ('*')

# %%
data.head
data
# Out:
# <bound method NDFrame.head of         TID              OMRÅDE  INDHOLD
# 0    2008K2         Hele landet  5482266
# 1    2008K2  Region Hovedstaden  1648990
# 2    2008K2           København   511725
# 3    2008K2       Frederiksberg    93848
# 4    2008K2              Dragør    13315
# 5    2008K2              Tårnby    40002
# 6    2008K2         Albertslund    27564
# 7    2008K2            Ballerup    47253
# 8    2008K2             Brøndby    33772
# 9    2008K2            Gentofte    68997
# 10   2008K2            Gladsaxe    62703
# 11   2008K2            Glostrup    20734
# 12   2008K2              Herlev    26574
# 13   2008K2            Hvidovre    49284
# 14   2008K2       Høje-Taastrup    47225
# 15   2008K2               Ishøj    20678
# 16   2008K2      Lyngby-Taarbæk    51508
# 17   2008K2             Rødovre    36163
# 18   2008K2          Vallensbæk    12710
# 19   2008K2             Allerød    23515
# 20   2008K2              Egedal    40733
# 21   2008K2         Fredensborg    39148
# 22   2008K2       Frederikssund    44150
# 23   2008K2              Furesø    37753
# 24   2008K2            Gribskov    40568
# 25   2008K2             Halsnæs    30767
# 26   2008K2           Helsingør    60832
# 27   2008K2            Hillerød    46607
# 28   2008K2            Hørsholm    24189
# 29   2008K2           Rudersdal    53859
# ..      ...                 ...      ...
# 75   2008K2           Hedensted    45649
# 76   2008K2             Horsens    80375
# 77   2008K2           Norddjurs    38522
# 78   2008K2               Odder    21563
# 79   2008K2             Randers    93803
# 80   2008K2               Samsø     4073
# 81   2008K2           Silkeborg    87586
# 82   2008K2         Skanderborg    56149
# 83   2008K2            Syddjurs    41257
# 84   2008K2              Aarhus   298710
# 85   2008K2             Herning    84466
# 86   2008K2           Holstebro    57172
# 87   2008K2        Ikast-Brande    39979
# 88   2008K2              Lemvig    21992
# 89   2008K2   Ringkøbing-Skjern    58426
# 90   2008K2               Skive    48312
# 91   2008K2              Struer    22680
# 92   2008K2              Viborg    92266
# 93   2008K2  Region Nordjylland   579148
# 94   2008K2         Brønderslev    35508
# 95   2008K2       Frederikshavn    62733
# 96   2008K2            Hjørring    67143
# 97   2008K2          Jammerbugt    39005
# 98   2008K2                Læsø     2009
# 99   2008K2       Mariagerfjord    42670
# 100  2008K2               Morsø    22166
# 101  2008K2              Rebild    28798
# 102  2008K2             Thisted    45609
# 103  2008K2     Vesthimmerlands    38362
# 104  2008K2             Aalborg   195145
#
# [105 rows x 3 columns]>

# %%
import matplotlib.pyplot as plt

plt.plot(x, data.TID, label="line L")
plt.plot()

plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("Line Graph Example")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-c096155bbed5> in <module>()
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 plt.plot(x, data.TID, label="line L")
#       4 plt.plot()
#       5
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3361                       mplDeprecation)
#    3362     try:
# -> 3363         ret = ax.plot(*args, **kwargs)
#    3364     finally:
#    3365         ax._hold = washold
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
#    1869         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, *args, **kwargs)
#    1526         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1527
# -> 1528         for line in self._get_lines(*args, **kwargs):
#    1529             self.add_line(line)
#    1530             lines.append(line)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _grab_next_args(self, *args, **kwargs)
#     404                 this += args[0],
#     405                 args = args[1:]
# --> 406             for seg in self._plot_args(this, kwargs):
#     407                 yield seg
#     408
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     381             x, y = index_of(tup[-1])
#     382
# --> 383         x, y = self._xy_from_xy(x, y)
#     384
#     385         if self.command == 'plot':
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _xy_from_xy(self, x, y)
#     240         if x.shape[0] != y.shape[0]:
#     241             raise ValueError("x and y must have same first dimension, but "
# --> 242                              "have shapes {} and {}".format(x.shape, y.shape))
#     243         if x.ndim > 2 or y.ndim > 2:
#     244             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (9,) and (105,)
